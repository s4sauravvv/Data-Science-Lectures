# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
emp={'Age_Years':[10,23,22,25,20,23,24,27,25,24,33,21],
    'Salary_Thousand':[15,22,24,25,30,23,34,43,19,20,52,21]}

# %%
df=pd.DataFrame(emp)

# %%
df
# Out:
#     Age_Years  Salary_Thousand
# 0          10               15
# 1          23               22
# 2          22               24
# 3          25               25
# 4          20               30
# 5          23               23
# 6          24               34
# 7          27               43
# 8          25               19
# 9          24               20
# 10         33               52
# 11         21               21

# %%
#Boxplot

# %%
plt.figure(figsize=(5,6))
ax=sns.boxplot(data=df)
plt.yticks(range(5,60,5))#range on y asix
plt.xlabel('Age and Salary')
plt.show()

# %% [markdown]
# Seaborn Version will keep changing.If code Doesn't work,Please refer official documentation
#  https://seaborn.pydata.org/

# %%
#Another way

# %%
df.plot(kind='box',figsize=(8,5),color='r',yticks=range(0,55,5))
# Out:
# <AxesSubplot:>

# %%
sal=[15,22,24,25,30,23,34,43,19,20,52,21]
sal.sort()
sal
# Out:
# [15, 19, 20, 21, 22, 23, 24, 25, 30, 34, 43, 52]

# %% [markdown]
# # Please see below Example
#
#
#
#
# [15,19,20,21,22,23,24,25,30,34,43,52]
#
#
#
#
# n=total elements in the above (12 items)
#
#
#
# --> 25%=(25/100) * (n+1)=3.25(data at 3.25 Position is the 25% percentile .lets say around 20.50)
#
#
#
#
# --> 50%=(50/100) * (n+1)=6.5(data at this position)
#
#
#
#
# --> 75%=(75/100) * (n+1)=9.75(data at this position)

# %% [markdown]
# # Outliers

# %%
import pandas as pd
ser=pd.Series(sal)
ser
# Out:
# 0     15
# 1     19
# 2     20
# 3     21
# 4     22
# 5     23
# 6     24
# 7     25
# 8     30
# 9     34
# 10    43
# 11    52
# dtype: int64

# %%
#1st Quantile
q1=ser.quantile(0.25)
print('Q1',q1)
#3rd Quantile
q3=ser.quantile(0.75)
print('Q3',q3)
#Find the IQR (inter quantile range) to identify outliers
iqr=q3-q1
print('IQR',iqr)
# Out:
# Q1 20.75
# Q3 31.0
# IQR 10.25

# %% [markdown]
# # Outliers Detection Formula
# higher side==> Q3 + (1.5 * IQR)
# lower side ==> Q1 - (1.5 * IQR)

# %%
upside=93 + (1.5 * iqr)
print(upside)
# Out:
# 108.375

# %%
#Anything above 43.373 is outlier

# %%
lower_side=q1-(1.5 * iqr)
print(lower_side)
# Out:
# 5.375

# %%
#Anything below 5.375 is outlier

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=iris.drop(['species'],axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#KDE-kernel density estimation

# %%
scatter_matrix(df,figsize=(10,8),color='r',diagonal='kde')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rupees_monthly=[2000,2530,900,1500,1500]
items=['Tution_Fee','Mobile_bill','Electricity_bill','Rent','Misc']

# %%
#---------------------------

# %%
#Plotting Data

# %%
plt.pie(x=rupees_monthly,labels=items)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(x=rupees_monthly,labels=items,explode=[0,0,0,0.1,0],autopct='%2f',rotatelabels=True)
plt.show()

# %%
#Numerical Data Plotting

# %%
#--> replot()
#--> Scatter Plot()
#--> inlineplot()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size')
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,size='size')
plt.show()

# %%
sns.lineplot(x='total_bill',y='tip',data=tips)
plt.show()

# %% [markdown]
# # Categorical Data Plotting

# %% [markdown]
# --> Catplot()
# --> Bosplot()
# --> Striplot()
# --> Swarmplot()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Catplot()

# %%
sns.catplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm',hue='size')

# %%
sns.stripplot(x='size',y='total_bill',data=tips)
plt.show()

# %%
sns.stripplot(x='smoker',y='total_bill',data=tips)
plt.show()

# %% [markdown]
# Visualizing Distribution of the data

# %% [markdown]
# --> distplot()
#
#
# --> kdeplot()
#
#
#
# --> jointplot()

# %%
import seaborn as sns
import pandas as pd
from numpy.random import randn
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
x=randn(100)

# %%
x
# Out:
# array([-0.32821473,  0.59492826, -0.05743402,  0.33373338, -0.81402816,
#        -0.47426841, -0.69734147,  0.91389437,  0.60228657,  0.8099469 ,
#        -1.74380657, -0.86545718,  0.30825738, -0.0841246 ,  0.00915759,
#         1.57926482, -1.37262716,  0.06600025,  0.3502069 ,  1.14776034,
#        -1.35210144, -0.47221684, -0.46337403, -0.37064886,  0.85307284,
#         0.43926756,  0.21659733,  0.87710635,  1.9800024 , -1.55542388,
#        -1.46328003,  0.39968998,  0.6692039 ,  0.74695242,  0.03247658,
#         1.17088107,  0.04214189, -0.25041385, -1.41544957,  0.58448958,
#        -1.05597651,  0.79684895, -1.03234122, -0.78401456,  0.58568529,
#         0.23421366,  0.2332194 , -0.75055676, -0.05443484,  0.51527398,
#        -0.98483684, -1.10738748,  1.40209272,  0.21641614,  3.96474214,
#        -0.45175362, -0.64157754,  0.62555274, -1.68945402,  1.33159737,
#         0.26179049, -0.66784318, -0.19383679,  1.94456589, -0.63341088,
#         0.09423328,  0.75404024, -1.07889842,  0.2371494 , -1.14561935,
#        -0.08131383, -0.92191091, -0.50004535,  0.34556306, -1.21060893,
#         0.50060979,  0.83865939, -1.5425245 , -0.73517312, -0.40890815,
#        -0.35937165,  0.85052623, -0.14626733,  0.3707674 ,  0.90248883,
#        -0.16459027, -0.6206456 ,  1.07003468, -1.16348439, -0.59777226,
#        -1.50747709,  0.05354082,  0.35707176,  0.39648058, -0.26440418,
#         0.57844925,  1.14181495, -0.17696372, -0.55609728,  1.34613638])

# %%
sns.distplot(x,kde=True,hist=False)
plt.show()

# %%
tist=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
x=tips['total_bill']
y=tips['tip']

# %%
sns.jointplot(x=x,y=y)

# %% [markdown]
# #  Linear Regression and Relationship

# %% [markdown]
# -->Regplot
#
#
#
# --> Implot

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)
plt.show()
